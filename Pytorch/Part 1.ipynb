# %%
conda update --all
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\xuchu\anaconda3\envs\tensorflow-venv
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cudatoolkit-11.0.221       |       h74a9793_0       627.0 MB
#     ------------------------------------------------------------
#                                            Total:       627.0 MB
#
# The following packages will be UPDATED:
#
#   cudatoolkit                            10.2.89-h74a9793_1 --> 11.0.221-h74a9793_0
#   python                                   3.7.6-h60c2a47_2 --> 3.7.9-h60c2a47_0
#
#
#
# ...
#
# cudatoolkit-11.0.221 | 627.0 MB  |            |   0%
# cudatoolkit-11.0.221 | 627.0 MB  |            |   0%
# cudatoolkit-11.0.221 | 627.0 MB  |            |   0%
# cudatoolkit-11.0.221 | 627.0 MB  |            |   0%
# cudatoolkit-11.0.221 | 627.0 MB  |            |   1%
# ...

# %%
import torch

# %%
print(torch.__version__)
# Out:
# 1.7.1

# %%
conda install pytorch torchvision torchaudio cpuonly -c pytorch
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\xuchu\anaconda3\envs\tensorflow-venv
#
#   added / updated specs:
#     - cpuonly
#     - pytorch
#     - torchaudio
#     - torchvision
#
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cpuonly-1.0                |                0           2 KB  pytorch
#     pytorch-1.7.1              |      py3.7_cpu_0       157.0 MB  pytorch
#     torchvision-0.8.2          |         py37_cpu         6.6 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:       163.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   cpuonly            pytorch/noarch::cpuonly-1.0-0
#   freetype           pkgs/main/win-64::freetype-2.10.4-hd328e21_0
# ...
